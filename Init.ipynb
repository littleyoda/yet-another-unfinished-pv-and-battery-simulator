# %%
import sys
# !{sys.executable} -m pip install --upgrade pvlib tabulate plotnine ipympl

# !conda install --yes --prefix {sys.prefix} ipywidgets ipympl
# Out:
# ...
#   Using cached pvlib-0.9.5-py3-none-any.whl (29.4 MB)
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...
#   Using cached plotnine-0.10.1-py3-none-any.whl (1.2 MB)
# ...
#   Using cached ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 9.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 9.0 MB/s eta 0:00:000m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 9.7 MB/s eta 0:00:000m eta 0:00:010:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 9.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached mizani-0.9.0-py3-none-any.whl (73 kB)
# ...
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 9.6 MB/s eta 0:00:000m eta 0:00:0136m0:00:01m
# ...
